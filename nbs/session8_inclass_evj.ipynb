# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-03-24 13:29:13.425194: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, 
                (3,3),
                padding = "same",
                input_shape = (32, 32, 3)))
model.add(Activation("relu"))
          
# FC classifier
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, 
              y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 12s 8ms/step - loss: 2.0369 - accuracy: 0.2763 - val_loss: 1.9587 - val_accuracy: 0.3020
# Epoch 2/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.8444 - accuracy: 0.3559 - val_loss: 1.8315 - val_accuracy: 0.3618
# Epoch 3/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7700 - accuracy: 0.3823 - val_loss: 1.7602 - val_accuracy: 0.3824
# Epoch 4/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.7140 - accuracy: 0.4024 - val_loss: 1.7275 - val_accuracy: 0.3914
# Epoch 5/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6695 - accuracy: 0.4150 - val_loss: 1.7420 - val_accuracy: 0.3834
# Epoch 6/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6316 - accuracy: 0.4312 - val_loss: 1.6645 - val_accuracy: 0.4122
# Epoch 7/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5981 - accuracy: 0.4409 - val_loss: 1.6232 - val_accuracy: 0.4272
# Epoch 8/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5681 - accuracy: 0.4513 - val_loss: 1.6175 - val_accuracy: 0.4374
# Epoch 9/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5407 - accuracy: 0.4593 - val_loss: 1.5884 - val_accuracy: 0.4412
# Epoch 10/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.5175 - accuracy: 0.4686 - val_loss: 1.7340 - val_accuracy: 0.3674
# Epoch 11/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4948 - accuracy: 0.4775 - val_loss: 1.5469 - val_accuracy: 0.4534
# Epoch 12/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4716 - accuracy: 0.4862 - val_loss: 1.4998 - val_accuracy: 0.4708
# Epoch 13/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4520 - accuracy: 0.4914 - val_loss: 1.5243 - val_accuracy: 0.4620
# Epoch 14/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4326 - accuracy: 0.4991 - val_loss: 1.4835 - val_accuracy: 0.4706
# Epoch 15/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.4133 - accuracy: 0.5057 - val_loss: 1.4708 - val_accuracy: 0.4756
# Epoch 16/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3957 - accuracy: 0.5102 - val_loss: 1.4911 - val_accuracy: 0.4752
# Epoch 17/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3789 - accuracy: 0.5154 - val_loss: 1.5296 - val_accuracy: 0.4492
# Epoch 18/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3629 - accuracy: 0.5222 - val_loss: 1.4449 - val_accuracy: 0.4938
# Epoch 19/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3474 - accuracy: 0.5270 - val_loss: 1.4286 - val_accuracy: 0.4882
# Epoch 20/20
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.3338 - accuracy: 0.5314 - val_loss: 1.4228 - val_accuracy: 0.4906

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.61      0.55      0.58      1000
#   automobile       0.51      0.76      0.61      1000
#         bird       0.58      0.17      0.27      1000
#          cat       0.42      0.18      0.25      1000
#         deer       0.54      0.35      0.42      1000
#          dog       0.31      0.67      0.42      1000
#         frog       0.55      0.56      0.56      1000
#        horse       0.60      0.52      0.56      1000
#         ship       0.62      0.63      0.63      1000
#        truck       0.54      0.59      0.56      1000
#
#     accuracy                           0.50     10000
#    macro avg       0.53      0.50      0.49     10000
# weighted avg       0.53      0.50      0.49     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_17911/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_4 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 128)               409728
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 16s 11ms/step - loss: 2.2714 - accuracy: 0.1424 - val_loss: 2.2257 - val_accuracy: 0.2012
# Epoch 2/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 2.1259 - accuracy: 0.2482 - val_loss: 2.0275 - val_accuracy: 0.2864
# Epoch 3/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.9694 - accuracy: 0.3047 - val_loss: 1.9354 - val_accuracy: 0.3158
# Epoch 4/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.8984 - accuracy: 0.3324 - val_loss: 1.8931 - val_accuracy: 0.3334
# Epoch 5/20
# 1407/1407 [==============================] - 15s 10ms/step - loss: 1.8379 - accuracy: 0.3554 - val_loss: 1.8190 - val_accuracy: 0.3618
# Epoch 6/20
# 1407/1407 [==============================] - 15s 10ms/step - loss: 1.7783 - accuracy: 0.3769 - val_loss: 1.7859 - val_accuracy: 0.3574
# Epoch 7/20
# 1407/1407 [==============================] - 15s 10ms/step - loss: 1.7196 - accuracy: 0.3977 - val_loss: 1.6977 - val_accuracy: 0.4102
# Epoch 8/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.6593 - accuracy: 0.4190 - val_loss: 1.6422 - val_accuracy: 0.4226
# Epoch 9/20
# 1407/1407 [==============================] - 15s 10ms/step - loss: 1.6004 - accuracy: 0.4355 - val_loss: 1.6314 - val_accuracy: 0.4152
# Epoch 10/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.5498 - accuracy: 0.4515 - val_loss: 1.6013 - val_accuracy: 0.4184
# Epoch 11/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.5080 - accuracy: 0.4664 - val_loss: 1.5166 - val_accuracy: 0.4648
# Epoch 12/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.4741 - accuracy: 0.4757 - val_loss: 1.5031 - val_accuracy: 0.4552
# Epoch 13/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.4462 - accuracy: 0.4857 - val_loss: 1.7412 - val_accuracy: 0.3948
# Epoch 14/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.4224 - accuracy: 0.4947 - val_loss: 1.4446 - val_accuracy: 0.4752
# Epoch 15/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3988 - accuracy: 0.5047 - val_loss: 1.4652 - val_accuracy: 0.4750
# Epoch 16/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3802 - accuracy: 0.5091 - val_loss: 1.4693 - val_accuracy: 0.4768
# Epoch 17/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3592 - accuracy: 0.5191 - val_loss: 1.3914 - val_accuracy: 0.4984
# Epoch 18/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3446 - accuracy: 0.5243 - val_loss: 1.4444 - val_accuracy: 0.4756
# Epoch 19/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3274 - accuracy: 0.5300 - val_loss: 1.3779 - val_accuracy: 0.5124
# Epoch 20/20
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.3111 - accuracy: 0.5375 - val_loss: 1.3854 - val_accuracy: 0.5126

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_17911/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 2s 5ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.63      0.54      0.58      1000
#   automobile       0.72      0.54      0.62      1000
#         bird       0.41      0.41      0.41      1000
#          cat       0.36      0.27      0.31      1000
#         deer       0.42      0.46      0.44      1000
#          dog       0.33      0.69      0.44      1000
#         frog       0.75      0.41      0.53      1000
#        horse       0.56      0.60      0.58      1000
#         ship       0.62      0.64      0.63      1000
#        truck       0.65      0.50      0.56      1000
#
#     accuracy                           0.51     10000
#    macro avg       0.54      0.51      0.51     10000
# weighted avg       0.54      0.51      0.51     10000
